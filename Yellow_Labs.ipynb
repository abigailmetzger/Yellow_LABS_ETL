# %%
from bs4 import BeautifulSoup as bs
import requests
import pandas as pd

# %%
url = 'https://www.akc.org/most-popular-breeds/2018-full-list/'

# %%
response = requests.get(url)

# %%
soup = bs(response.text, 'html.parser')

# %%
results = soup.find_all('td')
# print(results[1:5])

# %%
breeds = []
ranks = []
counter = 0
for result in results[2:]:
    data = result.text
    if (counter % 2) == 0:
        #data_2 = data[:-1]
        breeds.append(data)
    else:
        ranks.append(data)
    counter += 1
#     print(data)
#     print("------")

# %%
# test_df = pd.DataFrame(list(zip(breeds, ranks)))
# test_df.head()

# %%
rank_df = pd.DataFrame({"Breeds": breeds, "Ranks": ranks})
rank_df.sort_values("Breeds").head()
# Out:
#                 Breeds Ranks
# 147     Affenpinschers   148
# 112      Afghan Hounds   113
# 59   Airedale Terriers    60
# 46              Akitas    47
# 57   Alaskan Malamutes    58

# %%
csv_file = "dog_intelligence.csv"
intelligence_df = pd.read_csv(csv_file)
intelligence_df.sort_values("Breed").head(5)
# Out:
#                 Breed                                    Classification obey  \
# 53      Affenpinscher                        Above Average Working Dogs  70%
# 135      Afghan Hound  Lowest Degree of Working/Obedience Intelligence   NaN
# 36   Airedale Terrier                        Above Average Working Dogs  70%
# 102             Akita            Average Working/Obedience Intelligence  50%
# 93   Alaskan Malamute            Average Working/Obedience Intelligence  50%
#
#      reps_lower  reps_upper
# 53           16          25
# 135          81         100
# 36           16          25
# 102          26          40
# 93           26          40

# %%
csv_file = "akc_breed_info.csv"
breed_df = pd.read_csv(csv_file, encoding='ISO-8859-1')
breed_df.tail()
# Out:
#                  Breed height_low_inches height_high_inches weight_low_lbs  \
# 145           Papillon                 8                 11              5
# 146         Pomeranian                12                 12              3
# 147         Poodle Toy                10                 10             10
# 148    Toy Fox Terrier                10                 10              4
# 149  Yorkshire Terrier                 8                  8              3
#
#     weight_high_lbs
# 145              10
# 146               7
# 147              10
# 148               7
# 149               7

# %%
#breeds_df.sort_values('Breed').head(5)

# %%
new_df = pd.merge(breed_df, intelligence_df, on="Breed")
new_df.head(50)
# Out:
#                              Breed height_low_inches height_high_inches  \
# 0                            Akita                26                 28
# 1             Bernese Mountain Dog                23                 27
# 2                       Bloodhound                24                 26
# 3                           Borzoi                26                 28
# 4                      Bullmastiff                25                 27
# 5                       Great Dane                32                 32
# 6                   Great Pyrenees                27                 32
# 7                  Irish Wolfhound                28                 35
# 8                           Kuvasz                28                 30
# 9                          Mastiff                27                 30
# 10                    Newfoundland                26                 28
# 11                      Rottweiler                22                 27
# ...

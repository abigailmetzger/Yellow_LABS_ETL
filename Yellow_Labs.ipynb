# %% [markdown]
# # Yellow Labs
# ## Combining dog breed and intelligence data
# ### Lauren, Abigail, Brennan

# %%
# import dependencies
import pandas as pd
from sqlalchemy import create_engine

# %% [markdown]
# # Data Extraction

# %% [markdown]
# ## Extract dog intelligence data from a csv and create a dataframe

# %%
csv_file = "dog_intelligence.csv"
intelligence_df = pd.read_csv(csv_file)
intelligence_df.sort_values("Breed").head(5)
# Out:
#                 Breed                                    Classification obey  \
# 53      Affenpinscher                        Above Average Working Dogs  70%
# 135      Afghan Hound  Lowest Degree of Working/Obedience Intelligence   NaN
# 36   Airedale Terrier                        Above Average Working Dogs  70%
# 102             Akita            Average Working/Obedience Intelligence  50%
# 93   Alaskan Malamute            Average Working/Obedience Intelligence  50%
#
#      reps_lower  reps_upper
# 53           16          25
# 135          81         100
# 36           16          25
# 102          26          40
# 93           26          40

# %% [markdown]
# ## Extract dog breed data from a csv and create a dataframe

# %%
csv_file = "akc_breed_info.csv"
breed_df = pd.read_csv(csv_file, encoding='ISO-8859-1')
breed_df.tail()
# Out:
#                  Breed height_low_inches height_high_inches weight_low_lbs  \
# 145           Papillon                 8                 11              5
# 146         Pomeranian                12                 12              3
# 147         Poodle Toy                10                 10             10
# 148    Toy Fox Terrier                10                 10              4
# 149  Yorkshire Terrier                 8                  8              3
#
#     weight_high_lbs
# 145              10
# 146               7
# 147              10
# 148               7
# 149               7

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Merge the breed and intelligence dataframes on "Breed"

# %%
combined_df = pd.merge(breed_df, intelligence_df, on="Breed")
combined_df.tail(5)
# Out:
#                  Breed height_low_inches height_high_inches weight_low_lbs  \
# 100      Japanese Chin                 8                 11              4
# 101            Maltese                 8                 10              4
# 102           Papillon                 8                 11              5
# 103         Pomeranian                12                 12              3
# 104  Yorkshire Terrier                 8                  8              3
#
#     weight_high_lbs                       Classification obey  reps_lower  \
# 100              11  Fair Working/Obedience Intelligence  30%          41
# 101               6  Fair Working/Obedience Intelligence  30%          41
# 102              10                       Brightest Dogs  95%           1
# 103               7               Excellent Working Dogs  85%           5
# 104               7           Above Average Working Dogs  70%          16
#
#      reps_upper
# 100          80
# 101          80
# 102           4
# 103          15
# 104          25

# %% [markdown]
# ## Rename column headers

# %%
renamed_df = combined_df.rename(columns={'height_low_inches':'Min_Height_(In)',
                          'height_high_inches':'Max_Height_(In)',
                          'weight_low_lbs':'Min_Weight_(lbs)',
                                 'weight_high_lbs':'Max_Weight_(lbs)',
                                 'Classification':'Intelligence_Classification',
                                 'obey':'Successful_Initial_Response_Rate',
                                 'reps_lower':'Min_Reps_to_Understanding',
                                 'reps_upper':'Max_Reps_to_Understanding'},
                 inplace=False)
renamed_df.head(20)
# Out:
#                    Breed Min_Height_(In) Max_Height_(In) Min_Weight_(lbs)  \
# 0                  Akita              26              28               80
# 1   Bernese Mountain Dog              23              27               85
# 2             Bloodhound              24              26               80
# 3                 Borzoi              26              28               70
# 4            Bullmastiff              25              27              100
# 5             Great Dane              32              32              120
# 6         Great Pyrenees              27              32               95
# 7        Irish Wolfhound              28              35               90
# 8                 Kuvasz              28              30               70
# 9                Mastiff              27              30              175
# 10          Newfoundland              26              28              100
# 11            Rottweiler              22              27               90
# 12         Saint Bernard              25              28              110
# 13          Afghan Hound              25              27               50
# 14      Alaskan Malamute              na              na               na
# 15     American Foxhound              22              25               65
# 16      Belgian Malinois              22              26               60
# 17      Belgian Sheepdog              22              26               60
# 18                 Boxer              21              25               65
# 19                Briard              23              27               74
#
#    Max_Weight_(lbs)                       Intelligence_Classification  \
# 0               120            Average Working/Obedience Intelligence
# 1               110                            Excellent Working Dogs
# 2               120  Lowest Degree of Working/Obedience Intelligence
# 3               100  Lowest Degree of Working/Obedience Intelligence
# 4               130               Fair Working/Obedience Intelligence
# 5               160            Average Working/Obedience Intelligence
# 6               120               Fair Working/Obedience Intelligence
# 7               150            Average Working/Obedience Intelligence
# 8               120            Average Working/Obedience Intelligence
# 9               190  Lowest Degree of Working/Obedience Intelligence
# 10              150                        Above Average Working Dogs
# 11              110                                    Brightest Dogs
# 12              190               Fair Working/Obedience Intelligence
# 13               60  Lowest Degree of Working/Obedience Intelligence
# 14               na            Average Working/Obedience Intelligence
# 15               70            Average Working/Obedience Intelligence
# 16               65                            Excellent Working Dogs
# 17               75                            Excellent Working Dogs
# 18               70            Average Working/Obedience Intelligence
# 19               76                        Above Average Working Dogs
#
#    Successful_Initial_Response_Rate  Min_Reps_to_Understanding  \
# 0                               50%                         26
# 1                               85%                          5
# 2                               NaN                         81
# 3                               NaN                         81
# 4                               30%                         41
# 5                               50%                         26
# 6                               30%                         41
# 7                               50%                         26
# 8                               50%                         26
# 9                               NaN                         81
# 10                              70%                         16
# 11                              95%                          1
# 12                              30%                         41
# 13                              NaN                         81
# 14                              50%                         26
# 15                              50%                         26
# 16                              85%                          5
# 17                              85%                          5
# 18                              50%                         26
# 19                              70%                         16
#
#     Max_Reps_to_Understanding
# 0                          40
# 1                          15
# 2                         100
# 3                         100
# 4                          80
# 5                          40
# 6                          80
# 7                          40
# 8                          40
# 9                         100
# 10                         25
# 11                          4
# 12                         80
# 13                        100
# 14                         40
# 15                         40
# 16                         15
# 17                         15
# 18                         40
# 19                         25

# %% [markdown]
# ## Converted numerical columns into float datatypes for further analysis

# %%
renamed_df["Min_Height_(In)"] = pd.to_numeric(renamed_df["Min_Height_(In)"], errors='coerce')
renamed_df["Max_Height_(In)"] = pd.to_numeric(renamed_df["Max_Height_(In)"], errors='coerce')
renamed_df["Min_Weight_(lbs)"] = pd.to_numeric(renamed_df["Min_Weight_(lbs)"], errors='coerce')
renamed_df["Max_Weight_(lbs)"] = pd.to_numeric(renamed_df["Max_Weight_(lbs)"], errors='coerce')

# %%
renamed_df.head()
# Out:
#                   Breed  Min_Height_(In)  Max_Height_(In)  Min_Weight_(lbs)  \
# 0                 Akita             26.0             28.0              80.0
# 1  Bernese Mountain Dog             23.0             27.0              85.0
# 2            Bloodhound             24.0             26.0              80.0
# 3                Borzoi             26.0             28.0              70.0
# 4           Bullmastiff             25.0             27.0             100.0
#
#    Max_Weight_(lbs)                       Intelligence_Classification  \
# 0             120.0            Average Working/Obedience Intelligence
# 1             110.0                            Excellent Working Dogs
# 2             120.0  Lowest Degree of Working/Obedience Intelligence
# 3             100.0  Lowest Degree of Working/Obedience Intelligence
# 4             130.0               Fair Working/Obedience Intelligence
#
#   Successful_Initial_Response_Rate  Min_Reps_to_Understanding  \
# 0                              50%                         26
# 1                              85%                          5
# 2                              NaN                         81
# 3                              NaN                         81
# 4                              30%                         41
#
#    Max_Reps_to_Understanding
# 0                         40
# 1                         15
# 2                        100
# 3                        100
# 4                         80

# %% [markdown]
# ## Aggregate the height, weight, and repitition columns to get the average and insert those columns into the dataframe

# %%
renamed_df.insert(3, "Avg_Height_(In)", ((renamed_df["Min_Height_(In)"] + renamed_df["Max_Height_(In)"])/2), True)
renamed_df.insert(6, "Avg_Weight_(lbs)", ((renamed_df["Min_Weight_(lbs)"] + renamed_df["Max_Weight_(lbs)"])/2), True)
renamed_df.insert(11, "Avg_Reps_to_Understanding", ((renamed_df["Min_Reps_to_Understanding"] + renamed_df["Max_Reps_to_Understanding"])/2), True)
renamed_df.head()
# Out:
#                   Breed  Min_Height_(In)  Max_Height_(In)  Avg_Height_(In)  \
# 0                 Akita             26.0             28.0             27.0
# 1  Bernese Mountain Dog             23.0             27.0             25.0
# 2            Bloodhound             24.0             26.0             25.0
# 3                Borzoi             26.0             28.0             27.0
# 4           Bullmastiff             25.0             27.0             26.0
#
#    Min_Weight_(lbs)  Max_Weight_(lbs)  Avg_Weight_(lbs)  \
# 0              80.0             120.0             100.0
# 1              85.0             110.0              97.5
# 2              80.0             120.0             100.0
# 3              70.0             100.0              85.0
# 4             100.0             130.0             115.0
#
#                         Intelligence_Classification  \
# 0            Average Working/Obedience Intelligence
# 1                            Excellent Working Dogs
# 2  Lowest Degree of Working/Obedience Intelligence
# 3  Lowest Degree of Working/Obedience Intelligence
# 4               Fair Working/Obedience Intelligence
#
#   Successful_Initial_Response_Rate  Min_Reps_to_Understanding  \
# 0                              50%                         26
# 1                              85%                          5
# 2                              NaN                         81
# 3                              NaN                         81
# 4                              30%                         41
#
#    Max_Reps_to_Understanding  Avg_Reps_to_Understanding
# 0                         40                       33.0
# 1                         15                       10.0
# 2                        100                       90.5
# 3                        100                       90.5
# 4                         80                       60.5

# %% [markdown]
# ## Set the dataframe index to "Breed"

# %%
renamed_df.set_index("Breed").head()
# Out:
#                       Min_Height_(In)  Max_Height_(In)  Avg_Height_(In)  \
# Breed
# Akita                            26.0             28.0             27.0
# Bernese Mountain Dog             23.0             27.0             25.0
# Bloodhound                       24.0             26.0             25.0
# Borzoi                           26.0             28.0             27.0
# Bullmastiff                      25.0             27.0             26.0
#
#                       Min_Weight_(lbs)  Max_Weight_(lbs)  Avg_Weight_(lbs)  \
# Breed
# Akita                             80.0             120.0             100.0
# Bernese Mountain Dog              85.0             110.0              97.5
# Bloodhound                        80.0             120.0             100.0
# Borzoi                            70.0             100.0              85.0
# Bullmastiff                      100.0             130.0             115.0
#
#                                            Intelligence_Classification  \
# Breed
# Akita                           Average Working/Obedience Intelligence
# Bernese Mountain Dog                            Excellent Working Dogs
# Bloodhound            Lowest Degree of Working/Obedience Intelligence
# Borzoi                Lowest Degree of Working/Obedience Intelligence
# Bullmastiff                        Fair Working/Obedience Intelligence
#
#                      Successful_Initial_Response_Rate  \
# Breed
# Akita                                             50%
# Bernese Mountain Dog                              85%
# Bloodhound                                        NaN
# Borzoi                                            NaN
# Bullmastiff                                       30%
#
#                       Min_Reps_to_Understanding  Max_Reps_to_Understanding  \
# Breed
# Akita                                        26                         40
# Bernese Mountain Dog                          5                         15
# Bloodhound                                   81                        100
# Borzoi                                       81                        100
# Bullmastiff                                  41                         80
#
#                       Avg_Reps_to_Understanding
# Breed
# Akita                                      33.0
# Bernese Mountain Dog                       10.0
# Bloodhound                                 90.5
# Borzoi                                     90.5
# Bullmastiff                                60.5

# %% [markdown]
# # Loading the Data into a MySQL Database
# * We chose MySQL because our data was tabular, and we didn't require flexibility in our data's structure

# %% [markdown]
# ## Create a New MySQL Database

# %%
create_engine('mysql://root:LaurensMySQL11@localhost').execute('CREATE DATABASE IF NOT EXISTS labs_db')

# %% [markdown]
# ## Connect to our new MySQL database

# %%
rds_connection_string = "root:LaurensMySQL11@127.0.0.1/labs_db"
engine = create_engine(f'mysql://{rds_connection_string}')

# %% [markdown]
# ## Load our table of dogs into our new database

# %%
renamed_df.to_sql(name='labs_data', con=engine, if_exists='fail', index=False)

# %% [markdown]
# ## Confirm the data was loaded into the database by querying it

# %%
pd.read_sql_query('select * from labs_data', con=engine).head()
# Out:
#                   Breed  Min_Height_(In)  Max_Height_(In)  Avg_Height_(In)  \
# 0                 Akita             26.0             28.0             27.0
# 1  Bernese Mountain Dog             23.0             27.0             25.0
# 2            Bloodhound             24.0             26.0             25.0
# 3                Borzoi             26.0             28.0             27.0
# 4           Bullmastiff             25.0             27.0             26.0
#
#    Min_Weight_(lbs)  Max_Weight_(lbs)  Avg_Weight_(lbs)  \
# 0              80.0             120.0             100.0
# 1              85.0             110.0              97.5
# 2              80.0             120.0             100.0
# 3              70.0             100.0              85.0
# 4             100.0             130.0             115.0
#
#                         Intelligence_Classification  \
# 0            Average Working/Obedience Intelligence
# 1                            Excellent Working Dogs
# 2  Lowest Degree of Working/Obedience Intelligence
# 3  Lowest Degree of Working/Obedience Intelligence
# 4               Fair Working/Obedience Intelligence
#
#   Successful_Initial_Response_Rate  Min_Reps_to_Understanding  \
# 0                              50%                         26
# 1                              85%                          5
# 2                             None                         81
# 3                             None                         81
# 4                              30%                         41
#
#    Max_Reps_to_Understanding  Avg_Reps_to_Understanding
# 0                         40                       33.0
# 1                         15                       10.0
# 2                        100                       90.5
# 3                        100                       90.5
# 4                         80                       60.5
